# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from pprint import pprint

from api_keys import geoapify_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import json
#       6 from pprint import pprint
# ----> 8 from api_keys import geoapify_key
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
education_df = pd.read_csv(r"C:\Users\juank\OneDrive\Desktop\Everything\UofT\Project_1\Project_1\Datasets\Education.csv")
education_df.head()
# Out:
#    BLcode  country  year sex  agefrom  ageto     lu     lp   lpc    ls   lsc  \
# 0       1  Algeria  1950  MF       15     64  81.12  17.10  3.65  1.48  0.50
# 1       1  Algeria  1955  MF       15     64  81.50  16.54  3.43  1.66  0.53
# 2       1  Algeria  1960  MF       15     64  82.50  14.29  3.16  2.88  1.02
# 3       1  Algeria  1965  MF       15     64  80.08  15.00  4.21  4.46  1.90
# 4       1  Algeria  1970  MF       15     64  72.02  20.25  6.06  7.25  3.87
#
#      lh   lhc  yr_sch  yr_sch_pri  yr_sch_sec  yr_sch_ter WBcode  \
# 0  0.30  0.18   0.834       0.729       0.095       0.010    DZA
# 1  0.26  0.17   0.823       0.714       0.100       0.008    DZA
# 2  0.33  0.19   0.896       0.716       0.169       0.010    DZA
# 3  0.45  0.24   1.151       0.871       0.267       0.014    DZA
# 4  0.38  0.18   1.690       1.247       0.432       0.011    DZA
#
#                     region_code     pop
# 0  Middle East and North Africa  4858.0
# ...

# %%
education_df = education_df.set_index('WBcode')
education_df = education_df.drop('BLcode', axis=1)
education_df
# Out:
#         country  year sex  agefrom  ageto     lu     lp   lpc     ls    lsc  \
# WBcode
# DZA     Algeria  1950  MF       15     64  81.12  17.10  3.65   1.48   0.50
# DZA     Algeria  1955  MF       15     64  81.50  16.54  3.43   1.66   0.53
# DZA     Algeria  1960  MF       15     64  82.50  14.29  3.16   2.88   1.02
# DZA     Algeria  1965  MF       15     64  80.08  15.00  4.21   4.46   1.90
# DZA     Algeria  1970  MF       15     64  72.02  20.25  6.06   7.25   3.87
# ...         ...   ...  ..      ...    ...    ...    ...   ...    ...    ...
# UKR     Ukraine  1995  MF       15     64   1.49   6.41  5.38  62.19  44.42
# UKR     Ukraine  2000  MF       15     64   0.52   3.19  2.85  59.08  43.18
# UKR     Ukraine  2005  MF       15     64   0.29   3.82  3.56  56.51  43.04
# UKR     Ukraine  2010  MF       15     64   0.23   5.02  4.76  52.34  41.00
# UKR     Ukraine  2015  MF       15     64   0.24   6.34  6.04  49.08  39.18
#
# ...

# %%
base_url = "https://api.geoapify.com/v1/geocode/search"
params = {
    "apiKey":geoapify_key,
    "format":"json",
    "limit": 1
}



education_df = education_df.reindex(columns = education_df.columns.tolist() + ['geo_country'])
education_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 base_url = "https://api.geoapify.com/v1/geocode/search"
#       2 params = {
# ----> 3     "apiKey":geoapify_key,
#       4     "format":"json",
#       5     "limit": 1
#       6 }
#      10 education_df = education_df.reindex(columns = education_df.columns.tolist() + ['geo_country'])
#      11 education_df
#
# NameError: name 'geoapify_key' is not defined
